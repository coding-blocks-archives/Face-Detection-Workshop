# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("/content/group_photo.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (333, 500, 3)

# %%
import cv2

# %%
model = cv2.CascadeClassifier("/content/haarcascade_frontalface_alt (1).xml")

# %%
faces = model.detectMultiScale(img)

# %%
faces
# Out:
# array([[374,  34,  55,  55],
#        [ 63,  38,  59,  59],
#        [296,  24,  56,  56],
#        [207,  72,  53,  53],
#        [439,  92,  49,  49],
#        [108,  86,  48,  48],
#        [168, 118,  46,  46]], dtype=int32)

# %%
faces.shape
# Out:
# (7, 4)

# %%
for face in faces:
  x,y,w,h = face

  img = cv2.rectangle(img, (x,y), (x+w, y+h), (0,0,0), 2 )

# %%
plt.imshow(img)
